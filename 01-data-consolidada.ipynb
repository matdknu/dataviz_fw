# %% [markdown]
# # Base Homologada: Revisar-

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
from pathlib import Path

# %%
# Cargar base desde CSV
base_total = pd.read_excel("bbdd/base_total_homologada.xlsx")

# Ver las primeras filas
print(base_total.head())

base_total
# Out:
#    anio                                           CARRERA  \
# 0  2020                                        Astronomía
# 1  2023                                     Bioingeniería
# 2  2023                              Ingeniería Comercial
# 3  2020                             Nutrición y Dietética
# 4  2020  Traducción/Interpretación en Idiomas Extranjeros
#
#                INGRESO  PTJE PONDERADO  PTJE_PONDERADO_PACE NACIONALIDAD  \
# 0  Técnico Profesional          644.40                  NaN      Chilena
# 1  Técnico Profesional          646.95                  NaN      Chilena
# 2  Técnico Profesional          641.40                  NaN      Chilena
# 3  Técnico Profesional          585.50                  NaN      Chilena
# 4  Técnico Profesional          580.00                  NaN      Chilena
#
#         SEXO                             NOMBRE_COLEGIO_EGRESO  \
# 0  MASCULINO                         LICEO TECNICO ANTOFAGASTA
# ...

# %%
# Crear DataFrame con los nombres únicos de carreras
df_carreras_distintas = pd.DataFrame(base_total["CARRERA"].unique(), columns=["CARRERA"]) \
    .sort_values("CARRERA") \
    .reset_index(drop=True)

# Mostrar el DataFrame
print(df_carreras_distintas)
# Out:
#                                              CARRERA
# 0          Administración Pública y Ciencia Política
# 1                                          Agronomía
# 2                                       Antropología
# 3                                       Arquitectura
# 4                                     Artes Visuales
# ..                                               ...
# 76                                        Sociología
# 77                                            Teatro
# 78                                 Tecnología Médica
# 79                                    Trabajo Social
# 80  Traducción/Interpretación en Idiomas Extranjeros
#
# [81 rows x 1 columns]

# %%
# Crear DataFrame asegurando que todo sea string
df_carreras_distintas = pd.DataFrame(base_total["NACIONALIDAD"].astype(str).unique(), columns=["NACIONALIDAD"]) \
    .sort_values("NACIONALIDAD") \
    .reset_index(drop=True)

# Mostrar el DataFrame
print(df_carreras_distintas)
# Out:
#   NACIONALIDAD
# 0            -
# 1      Chilena
# 2   Extranjera
# 3          S/I
# 4          nan

# %%
# Crear DataFrame con los nombres únicos de carreras
df_carreras_distintas = pd.DataFrame(base_total["CARRERA"].unique(), columns=["CARRERA"]) \
    .sort_values("CARRERA") \
    .reset_index(drop=True)

# Mostrar el DataFrame
print(df_carreras_distintas)
# Out:
#                                              CARRERA
# 0          Administración Pública y Ciencia Política
# 1                                          Agronomía
# 2                                       Antropología
# 3                                       Arquitectura
# 4                                     Artes Visuales
# ..                                               ...
# 76                                        Sociología
# 77                                            Teatro
# 78                                 Tecnología Médica
# 79                                    Trabajo Social
# 80  Traducción/Interpretación en Idiomas Extranjeros
#
# [81 rows x 1 columns]

# %%
# Crear DataFrame con los nombres únicos de carreras
# Convertir todos los valores a string para evitar errores de ordenamiento
df_carreras_distintas = pd.DataFrame(base_total["INGRESO"].astype(str).unique(), columns=["INGRESO"]) \
    .sort_values("INGRESO") \
    .reset_index(drop=True)

# Mostrar el DataFrame
print(df_carreras_distintas)
# Out:
#                                   INGRESO
# 0                     Arte-Ciencia-Letras
# 1                            Bachillerato
# 2        Buen Rendimiento Enseñanza Media
# 3                    Colegios Vulnerables
# 4             Deportista Alto Rendimiento
# 5   Destacado en Artes, Ciencias o Letras
# 6                                   Etnia
# 7                    Excelencia Académica
# 8                               Excepción
# 9                                 Explora
# 10                 Formación Propedéutica
# 11                                 Género
# 12                    Hijo de Funcionario
# 13                       Mejores Puntajes
# 14                                   PACE
# 15                                Regular
# 16                    Técnico Profesional
# 17                                    nan

# %%
df_carreras_distintas = pd.DataFrame(base_total["SEXO"].astype(str).unique(), columns=["SEXO"]) \
    .sort_values("SEXO") \
    .reset_index(drop=True)

# Mostrar el DataFrame
print(df_carreras_distintas)
# Out:
#         SEXO
# 0   FEMENINO
# 1  MASCULINO
# 2        nan

# %%
df_carreras_distintas = pd.DataFrame(base_total["GRUPO_DEPENDENCIA_EST"].astype(str).unique(), columns=["GRUPO_DEPENDENCIA_EST"]) \
    .sort_values("GRUPO_DEPENDENCIA_EST") \
    .reset_index(drop=True)

# Mostrar el DataFrame
print(df_carreras_distintas)
# Out:
#          GRUPO_DEPENDENCIA_EST
# 0                    MUNICIPAL
# 1         PARTICULARES PAGADOS
# 2  PARTICULARES SUBVENCIONADOS
# 3              SIN INFORMACIÓN
# 4                         SLEP
